# %% [markdown]
# ## [Practice 4] Mask_detection
# * 0. 실습 환경 설정
# * 1. 데이터 준비하기
#     * 1-1. 데이터 전처리하기
#     * 1-2. Config file 만들기
# * 2. Training
# * 3. Testing
# * 4. Inference

# %% [markdown]
# ### 0. 실습 환경 설정
# * 가상환경명 : yolov8
# * Python 버전 : python 3.8
# * 설치 목록
#     * !pip install ultralytics
#     * !pip install opencv-python

# %%
#### ====================== CODE 채우기 ======================
# yolo8 라이브러리 설치 확인하기
import ultralytics
ultralytics.checks()

#### ====================== CODE 채우기 ======================
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.11.4 torch-2.1.0 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 120.5/228.3 GB disk)

# %% [markdown]
# ### 1. 데이터 준비하기
# ### 1-1. 데이터 전처리하기

# %% [markdown]
# * TODO : 데이터셋 다운로드 [링크](https://drive.google.com/drive/folders/1aAXDTl5kMPKAHE08WKGP2PifIdc21-ZG)
# * TODO : `mask_root`에 위 데이터셋 담겨있는 폴더 경로 넣어주기
# * TODO : 경로 변경 (데이터셋 저장하고 싶은 위치로)

# %%
cd /Users/oho/code files/Autonomous_driving_projects/Perception/Object detection/Project 1

# %%
cd

# %%
import os
import random
import shutil

mask_root = 
mask_path = 'mask_detection/'
label_ = '.txt'
img_ = '.jpg'
file_list = [file for file in os.listdir(mask_root) if file.endswith(".txt")]

# 저장 경로 만들기
folder_list = ['mask_detection', 'mask_detection/train', 'mask_detection/val', 'mask_detection/train/images', \
                'mask_detection/train/labels', 'mask_detection/val/images', 'mask_detection/val/labels']
for folder in folder_list:
    if not os.path.exists(folder):
        os.makedirs(folder)

# %%
#### ====================== CODE 채우기 ======================
# TODO 데이터셋 Train/Test 분리
# 1. Shuffle

# 2. Train/Test 분리

# 3. File 이동

#### ====================== CODE 채우기 ======================

# %% [markdown]
# ### 1-2. Config file 만들기

# %% [markdown]
# * TODO : project_mask_detection 폴더 만들기
# * TODO : 위치 변경 (project_mask_detection 폴더로)
# * TODO : data['train'], data['val'], data['test'] 입력해주기
#     * 'mask_detection있는 경로 + mask_detection/train'
#     * 'mask_detection있는 경로 + mask_detection/val'
#     * 'mask_detection있는 경로 + mask_detection/val'

# %%
cd

# %%
import yaml
data =dict()

data['train'] = 
data['val'] = 
data['test'] = 

data['nc'] = 3
data['names'] =['OK','improperly', 'NO']

with open('mask_detection.yaml', 'w') as f:
	yaml.dump(data, f)

# %% [markdown]
# ### 2. Training

# %% [markdown]
# * TODO : 위치 변경 (project_mask_detection 폴더로)

# %%
cd

# %%
from ultralytics import YOLO
model = YOLO('yolov8s.yaml')
results = model.train(data ='mask_detection.yaml', epochs = 100, batch=32,device = 0  , patience=30, name='road_sign_s')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2147008  ultralytics.nn.modules.head.Detect           [80, [128, 256, 512]]
# YOLOv8s summary: 225 layers, 11166560 parameters, 11166544 gradients
#
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=road_sign.yaml, epochs=100, patience=30, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=road_sign_s, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/ultralytics/runs/detect/road_sign_s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117596  ultralytics.nn.modules.head.Detect           [4, [128, 256, 512]]
# YOLOv8s summary: 225 layers, 11137148 parameters, 11137132 gradients
#
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/dataset/road_sign/train/labels... 790 images, 0 backgrounds, 0 corrupt: 100%|██████████| 790/790 [09:43<00:00,  1.35it/s]
# train: New cache created: /content/drive/MyDrive/dataset/road_sign/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/dataset/road_sign/val/labels... 87 images, 0 backgrounds, 0 corrupt: 100%|██████████| 87/87 [02:21<00:00,  1.63s/it]
# val: New cache created: /content/drive/MyDrive/dataset/road_sign/val/labels.cache
# Plotting labels to /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s/labels.jpg...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      7.88G      3.689      5.363      4.318         71        640: 100%|██████████| 25/25 [00:22<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.69s/it]
#                    all         87        112     0.0003      0.229   0.000382   0.000155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.86G      3.321      4.303       3.84         44        640: 100%|██████████| 25/25 [00:19<00:00,  1.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
#                    all         87        112   0.000289      0.229    0.00227     0.0011
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.87G      2.686      3.454      3.254         52        640: 100%|██████████| 25/25 [00:22<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
#                    all         87        112   0.000369      0.206   0.000547   0.000174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.87G       2.27      2.768      2.766         52        640: 100%|██████████| 25/25 [00:21<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
#                    all         87        112    0.00224      0.051    0.00898    0.00515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      7.87G       1.89      2.141      2.299         57        640: 100%|██████████| 25/25 [00:19<00:00,  1.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
#                    all         87        112      0.701      0.244      0.298      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.87G      1.666      1.795      2.032         51        640: 100%|██████████| 25/25 [00:19<00:00,  1.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.05s/it]
#                    all         87        112      0.962      0.377      0.417      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.87G      1.529      1.559      1.908         64        640: 100%|██████████| 25/25 [00:19<00:00,  1.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
#                    all         87        112      0.909      0.488      0.596      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.86G      1.391      1.402      1.746         59        640: 100%|██████████| 25/25 [00:20<00:00,  1.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
#                    all         87        112      0.604      0.545      0.512       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.87G      1.273      1.268      1.691         58        640: 100%|██████████| 25/25 [00:19<00:00,  1.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
#                    all         87        112      0.913      0.509      0.562      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.87G      1.194      1.205      1.592         42        640: 100%|██████████| 25/25 [00:19<00:00,  1.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
#                    all         87        112      0.851      0.486      0.576      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.87G      1.176       1.09      1.525         63        640: 100%|██████████| 25/25 [00:22<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
#                    all         87        112      0.765      0.509      0.631      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      7.87G      1.116      1.017      1.469         65        640: 100%|██████████| 25/25 [00:23<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
#                    all         87        112      0.706      0.569      0.622      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.87G      1.081      1.009      1.443         59        640: 100%|██████████| 25/25 [00:19<00:00,  1.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
#                    all         87        112      0.982      0.516      0.686      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.86G     0.5223     0.3293     0.9721         37        640: 100%|██████████| 25/25 [00:17<00:00,  1.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
#                    all         87        112      0.903      0.901      0.935      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.87G     0.5183     0.3151     0.9606         31        640: 100%|██████████| 25/25 [00:18<00:00,  1.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
#                    all         87        112      0.897      0.932       0.93      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.87G     0.5109     0.3063     0.9553         31        640: 100%|██████████| 25/25 [00:21<00:00,  1.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
#                    all         87        112       0.92      0.907      0.935      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.87G     0.5181     0.3134     0.9525         32        640: 100%|██████████| 25/25 [00:17<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
#                    all         87        112      0.932      0.846      0.887      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.87G     0.5073     0.3034     0.9676         38        640: 100%|██████████| 25/25 [00:19<00:00,  1.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
#                    all         87        112      0.936      0.919       0.94      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.87G     0.5135     0.3069     0.9574         31        640: 100%|██████████| 25/25 [00:20<00:00,  1.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
#                    all         87        112      0.928      0.889      0.938      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.87G     0.5046     0.2973      0.956         33        640: 100%|██████████| 25/25 [00:17<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
#                    all         87        112      0.933      0.909      0.939      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.87G     0.4965      0.306     0.9543         26        640: 100%|██████████| 25/25 [00:19<00:00,  1.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
#                    all         87        112      0.891      0.919      0.934      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.87G     0.4973     0.2937     0.9388         30        640: 100%|██████████| 25/25 [00:17<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.03s/it]
#                    all         87        112      0.868      0.914      0.935      0.785
#
# 100 epochs completed in 0.691 hours.
# Optimizer stripped from /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s/weights/last.pt, 22.5MB
# Optimizer stripped from /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s/weights/best.pt, 22.5MB
#
# Validating /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s/weights/best.pt...
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11127132 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
#                    all         87        112      0.936      0.918       0.94      0.793
#           Trafic_light         87         11          1      0.677       0.79      0.487
#             Speedlimit         87         80      0.978          1      0.995      0.921
#              Crosswalk         87         15      0.937      0.997      0.979      0.821
#                   Stop         87          6      0.828          1      0.995      0.942
# Speed: 3.3ms preprocess, 5.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /content/drive/MyDrive/ultralytics/runs/detect/road_sign_s

# %% [markdown]
# ### 3. Testing (Validation)

# %% [markdown]
# * TODO : 위치 변경 (project_mask_detection 폴더로)
# * TODO : 학습한 가중치 위치 `model_path`에 넣어주기

# %%
cd

# %%
model_path = 
#### ====================== CODE 채우기 ======================
# 1. import library


# 2. Load a model


# 3. Validate the model

#### ====================== CODE 채우기 ======================

print("map50-95", metrics.box.map)
print("map50", metrics.box.map50)

# %% [markdown]
# ### 4. Inference

# %%
cd C:/Users/minso/Documents/lecture/mask_detection
# Out:
# C:\Users\minso\Documents\lecture\mask_detection

# %%
from ultralytics import YOLO
import cv2
import os
from ultralytics.yolo.utils.plotting import Annotator
import matplotlib.pyplot as plt
import numpy as np

model = YOLO('best_mask.pt')

root_folder = '../dataset/mask_detection/val/images'
result_folder = '../dataset/mask_detection/result'
if not os.path.exists(result_folder):
    os.makedirs(result_folder)

test_img_list = os.listdir(root_folder)
device = 'cpu'
color_dict = [(0, 255, 0), (255, 0, 0), (0, 0, 255)]

# %%
#### ====================== CODE 채우기 ======================
# 마스크 인식 Inference 코드 작성
# 1. Read Image

# 2. Inference

# 3. Visualization

#### ====================== CODE 채우기 ======================
# Out:
# 0: 640x448 1 OK, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 448)

# %%
for idx , file in enumerate(test_img_list):
    test_img = cv2.imread(os.path.join(root_folder, file))
    img_src = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
    results = model(test_img)

    for result in results:
        annotator = Annotator(img_src)
        boxes = result.boxes
        for box in boxes:
            b = box.xyxy[0]  # get box coordinates in (top, left, bottom, right) format
            cls = box.cls
            annotator.box_label(b, model.names[int(cls)], color_dict[int(cls)])
    img_src = annotator.result()
    cv2.imwrite(os.path.join(result_folder, file), cv2.cvtColor(img_src, cv2.COLOR_RGB2BGR))
# Out:
# 0: 640x448 1 OK, 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 448x640 2 OKs, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 3 OKs, 11.7ms
# Speed: 4.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 8 OKs, 11.0ms
# Speed: 6.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 3 OKs, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 OKs, 2 NOs, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 10 OKs, 17 NOs, 11.0ms
# Speed: 6.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 OK, 1 NO, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 OKs, 2 improperlys, 3 NOs, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 OK, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 4 OKs, 1 NO, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 480x640 7 OKs, 13.0ms
# Speed: 5.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 608x640 4 OKs, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 480x640 2 OKs, 1 NO, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 2 OKs, 4 NOs, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 OK, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x544 1 improperly, 1 NO, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 448x640 4 OKs, 1 improperly, 17.9ms
# Speed: 5.0ms preprocess, 17.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 512x640 6 OKs, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x448 1 OK, 19.0ms
# Speed: 4.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 448x640 10 OKs, 2 NOs, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 OKs, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 OK, 12.9ms
# Speed: 7.0ms preprocess, 12.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 OK, 1 NO, 14.8ms
# Speed: 5.0ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 14 OKs, 1 improperly, 4 NOs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 OK, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 9.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 20 OKs, 1 improperly, 2 NOs, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 3 OKs, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 OK, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 3 OKs, 1 improperly, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x448 1 OK, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 384x640 5 OKs, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 OKs, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 OKs, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 8 OKs, 4 NOs, 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 OK, 18.0ms
# Speed: 7.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 OKs, 1 NO, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 1 OK, 2 NOs, 16.0ms
# Speed: 5.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 4 OKs, 4 NOs, 18.9ms
# Speed: 4.0ms preprocess, 18.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 3 OKs, 1 NO, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 19 OKs, 1 improperly, 2 NOs, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 OKs, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 21 OKs, 1 improperly, 4 NOs, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 2 OKs, 18.0ms
# Speed: 6.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 1 OK, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 6.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 4 OKs, 1 improperly, 1 NO, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 21 OKs, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 OK, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 480x640 2 OKs, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 OK, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 improperly, 1 NO, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 OK, 21.9ms
# Speed: 4.0ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 OK, 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 448x640 8 OKs, 1 improperly, 2 NOs, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 4 OKs, 2 NOs, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 5 OKs, 1 improperly, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x448 1 OK, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 OK, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 448x640 3 OKs, 1 NO, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 OKs, 2 NOs, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 6 OKs, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 7 OKs, 2 NOs, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 5 OKs, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 8 OKs, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 11 OKs, 2 NOs, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 OKs, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 4 OKs, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
